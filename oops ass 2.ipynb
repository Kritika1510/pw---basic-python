# %% [raw]
# Q1. Class and Object: In object-oriented programming (OOP), a class is a blueprint for creating objects (instances). It defines the attributes and methods that the objects of the class will have. An object is an instance of a class, which means it is a specific realization of that class. For example, consider a class `Car`, which may have attributes like `color`, `brand`, and methods like `drive()` and `stop()`. An object `my_car` created from this class would have specific values for its attributes, such as `color = 'red'` and `brand = 'Toyota'`.
#
# Q2. Four Pillars of OOPs:
#    - Encapsulation: The bundling of data and methods that operate on the data into a single unit, i.e., a class. It helps in hiding the internal state of an object from the outside world and only exposing the necessary functionalities.
#    - Abstraction: The concept of hiding the complex implementation details and showing only the necessary features of an object. It allows focusing on what an object does instead of how it achieves it.
#    - Inheritance: The mechanism of creating a new class (derived class) from an existing class (base class) such that the derived class inherits the properties and behavior of the base class.
#    - Polymorphism: The ability of different objects to respond to the same message or method call in different ways. It allows objects of different classes to be treated as objects of a common superclass.
#
# Q3. The `__init__()` function is used in Python to initialize the newly created object. It is called automatically when a new instance of the class is created. The primary purpose of `__init__()` is to set up the initial state of the object by initializing its attributes. Here's an example:
#
# class Car:
#     def __init__(self, color, brand):
#         self.color = color
#         self.brand = brand
#
# my_car = Car('red', 'Toyota')
#
#
# Q4. self` in OOPs: In Python, `self` is a reference to the current instance of the class. It is used to access variables and methods within the class. When defining methods in a class, the first parameter of the method is always `self`, which represents the instance on which the method is being called. It helps differentiate between instance variables and local variables within the class.
#
# Q5. Inheritance is a fundamental concept in OOP where a new class (derived class) is created by inheriting properties and behavior from an existing class (base class). This allows code reusability and establishes a hierarchical relationship between classes. There are different types of inheritance:
#    - Single Inheritance: When a class inherits from only one base class.
#
#      class Animal:
#          def sound(self):
#              print("Animal makes a sound")
#
#      class Dog(Animal):
#          def bark(self):
#              print("Dog barks")
#
#
#    Multiple Inheritance: When a class inherits from more than one base class.
#
#      class A:
#          def method_A(self):
#              print("Method A")
#
#      class B:
#          def method_B(self):
#              print("Method B")
#
#      class C(A, B):
#          pass
#
#    Multilevel Inheritance: When a derived class is created from another derived class.
#
#      class A:
#          pass
#
#      class B(A):
#          pass
#
#      class C(B):
#          pass
#
#    Hierarchical Inheritance: When more than one derived class is created from a single base class.
#
#      class Animal:
#          def sound(self):
#              print("Animal makes a sound")
#
#      class Dog(Animal):
#          def bark(self):
#              print("Dog barks")
#
#      class Cat(Animal):
#          def meow(self):
#              print("Cat meows")
